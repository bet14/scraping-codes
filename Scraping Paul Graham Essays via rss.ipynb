# %% [markdown]
# I want to save all the essays from Paul Graham rss to a document so I can read with my Kindle:
# - scrap all essays's url
# - scrap essay's title and content from urls then copy to a document

# %%
import feedparser
import csv

# RSS feed URL
rss_url = "http://www.aaronsw.com/2002/feeds/pgessays.rss"

# Parse the RSS feed
feed = feedparser.parse(rss_url)

# Extract URLs from the feed entries
urls = [entry.link for entry in feed.entries]

# Save the URLs to a CSV file
with open("D:/Paul_link.csv", "w", newline="", encoding="utf-8") as csvfile:
    writer = csv.writer(csvfile)
    writer.writerow(["URL"])

    for url in urls:
        writer.writerow([url])

print("URLs have been saved to D:/Paul_link.csv")
# Out:
# URLs have been saved to D:/Paul_link.csv

# %%
import csv
import requests
from bs4 import BeautifulSoup
from docx import Document

# Load URLs from CSV file
urls = []
with open("D:/Paul_link.csv", "r", newline="", encoding="utf-8") as csvfile:
    reader = csv.reader(csvfile)
    for row in reader:
        urls.extend(row)

# Initialize a Word document
doc = Document()

# Process each URL
for i, url in enumerate(urls, start=1):
    try:
        # Print the current URL being processed
        print(f"Processing URL {i}/{len(urls)}: {url}")

        # Fetch HTML content
        response = requests.get(url)
        soup = BeautifulSoup(response.text, "html.parser")

        # Extract title and content
        title = soup.title.text if soup.title else "Untitled"
        content = soup.get_text()

        # Add title as Heading 1
        doc.add_heading(title, level=1)

        # Add content
        doc.add_paragraph(content)

    except Exception as e:
        print(f"Error processing URL: {url}")
        print(e)

# Save Word document
doc.save("D:/Paul.docx")

print("Document saved as D:/Paul_Graham_Essays.docx")
# Out:
# Processing URL 1/220: URL
# Error processing URL: URL
# Invalid URL 'URL': No scheme supplied. Perhaps you meant https://URL?
# Processing URL 2/220: http://www.paulgraham.com/superlinear.html
# Processing URL 3/220: http://www.paulgraham.com/greatwork.html
# Processing URL 4/220: http://www.paulgraham.com/getideas.html
# Processing URL 5/220: http://www.paulgraham.com/read.html
# Processing URL 6/220: http://www.paulgraham.com/want.html
# Processing URL 7/220: http://www.paulgraham.com/alien.html
# Processing URL 8/220: http://www.paulgraham.com/users.html
# Processing URL 9/220: http://www.paulgraham.com/heresy.html
# Processing URL 10/220: http://www.paulgraham.com/words.html
# Processing URL 11/220: http://www.paulgraham.com/goodtaste.html
# Processing URL 12/220: http://www.paulgraham.com/smart.html
# Processing URL 13/220: http://www.paulgraham.com/weird.html
# Processing URL 14/220: http://www.paulgraham.com/hwh.html
# Processing URL 15/220: http://www.paulgraham.com/own.html
# ...
