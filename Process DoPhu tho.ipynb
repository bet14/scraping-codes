# %% [markdown]
# Xử lí tài liệu:
# - ghép từng phiên âm, phiên nghĩa vào từng câu chữ Hán
# - xóa bỏ phần thừa

# %%
import pandas as pd

# Đọc dữ liệu từ file CSV
df = pd.read_csv("D:/dophu_poem - Copy.csv")

# Tạo một cột mới để lưu phần ghép
df['Lồng ghép1'] = ""
df['Nghĩa tựa'] = ""

df['Chữ Hán'] = df['Chữ Hán'].str.replace("，", ",")
df['Chữ Hán'] = df['Chữ Hán'].str.replace("。", ",")
df['Chữ Hán'] = df['Chữ Hán'].str.replace("？", ",")
df['Chữ Hán'] = df['Chữ Hán'].str.replace("！", ",")

df['Phiên âm'] = df['Phiên âm'].str.replace(",", " ")
df['Phiên âm'] = df['Phiên âm'].str.replace("?", " ")
df['Phiên âm'] = df['Phiên âm'].str.replace(".", " ")
df['Phiên âm'] = df['Phiên âm'].str.replace("!", " ")
df['Phiên âm'] = df['Phiên âm'].str.replace(")", " ")
df['Phiên âm'] = df['Phiên âm'].str.replace(" (", "-")
df['Phiên âm'] = df['Phiên âm'].str.replace("  ", " ")

df['Tiêu đề'] = df['Tiêu đề'].str.replace("Bài thơ: ", "")
df['Tiêu đề'] = df['Tiêu đề'].str.replace("一 (Đỗ Phủ - 杜甫)", "")
df['Tiêu đề'] = df['Tiêu đề'].str.replace("-", "")
df['Tiêu đề'] = df['Tiêu đề'].str.replace("杜甫", "")
df['Tiêu đề'] = df['Tiêu đề'].str.replace("Đỗ Phủ", "")
df['Tiêu đề'] = df['Tiêu đề'].str.replace("一", "")
df['Tiêu đề'] = df['Tiêu đề'].str.replace(")", "")
df['Tiêu đề'] = df['Tiêu đề'].str.replace("(", "")
# Duyệt qua mỗi dòng của DataFrame
for index, row in df.iterrows():
    chinese_parts = row['Chữ Hán'].split(",")
    phonetic_parts = row['Phiên âm']
    translate_part= row['Phiên dịch'].split('\n')
    
    i=0
    
    # Tiếp tục xử lý như bình thường nếu số lượng phần tử trong mỗi phần tách của chinese_parts đều bằng nhau
    merged_text = ""
    n=0
    
    for i in range(len(chinese_parts)):
        han=chinese_parts[i].strip()
        k=len(chinese_parts[i].strip())
        
        
        phienam=phonetic_parts.split()[n:n+k]
       
        #print(k,n*k,(n+1)*k,phienam)
        phienam_str = ' '.join(phienam)
        
        
        
        if i+1 < len(translate_part):
            dich = translate_part[i+1].strip()
            print(han,'\n',phienam_str,'\n',dich)
            merged_text += f"{han}\n{phienam_str}\n{dich}\n\n"
        else:
            dich = ""
            merged_text += f"{han}\n{phienam_str}\n\n"
        n=n+k
    # Gán chuỗi lồng ghép mới vào cột 'Lồng ghép1' tương ứng
    df.at[index, 'Lồng ghép1'] = merged_text
     # Gán tựa đề
    df.at[index, 'Nghĩa tựa'] = translate_part[0].strip()
# Lưu DataFrame đã được cập nhật vào file CSV
df.to_csv("D:/dophu_poem_updated.csv", index=False,encoding='utf-8-sig')
print("Đã lưu dữ liệu đã được cập nhật vào file D:/dophu_poem_updated.csv")
# Out:
# 玉露凋傷楓樹林
#  Ngọc lộ điêu thương phong thụ lâm
#  Trong rừng phong, móc ngọc tơi bời,
# 巫山巫峽氣蕭森
#  Vu sơn Vu giáp khí tiêu sâm
#  Nơi núi Vu và kẽm Vu, khí ảm đạm hiu hắt.
# 江間波浪兼天湧
#  Giang gian ba lãng kiêm thiên dũng
#  Dưới lòng sông, sóng và trời (soi bóng) cùng dâng trào,
# 塞上風雲接地陰
#  Tái thượng phong vân tiếp địa âm
#  Ngoài ải, gió và mây tiếp nối với đất che mờ mịt.
# 叢菊兩開他日淚
#  Tùng cúc lưỡng khai tha nhật lệ
#  Khóm cúc dày đã hai lần nở chảy ra dòng lệ ngày trước,
# 孤舟一繫故園心
#  Cô chu nhất hệ cố viên tâm
#  Con thuyền lẻ loi vẫn buộc chặt nỗi lòng nhớ quê nhà.
# 寒衣處處催刀尺
#  Hàn y xứ xứ thôi đao xích
#  Nơi nơi giục giã dao thước may áo rét,
# 白帝城高急暮砧
#  Bạch Đế thành cao cấp mộ châm
#  Thành cao Bạch Đế tiếng chày đập áo lúc chiều tối dồn dập.
# 風急天高猿嘯哀
#  Phong cấp thiên cao viên khiếu ai
#  Gió thổi gấp, trời cao, vượn kêu buồn,
# 渚清沙白鳥飛回
#  Chử thanh sa bạch điểu phi hồi
#  Bến nước trong, cát trắng, chim bay lượn vòng.
# 無邊落木蕭蕭下
#  Vô biên lạc mộc tiêu tiêu há
# ...

# %%
import pandas as pd
from docx import Document

# Đọc dữ liệu từ file CSV
df = pd.read_csv("D:/dophu_poem_updated.csv")

# Tạo một đối tượng Document mới
doc = Document()

# Duyệt qua mỗi dòng của DataFrame
for index, row in df.iterrows():
    # Tiêu đề và nghĩa tựa
    title = row['Tiêu đề']
    meaning = row['Nghĩa tựa']
    
    # Tạo Heading 1 cho tiêu đề và nghĩa tựa
    doc.add_heading(f"{title} - {meaning}", level=1)
    
    # Lồng ghép1
    lồng_ghép = row['Lồng ghép1']
    
    # Thêm lồng ghép vào tài liệu
    doc.add_paragraph(lồng_ghép)

# Lưu tài liệu vào file DOCX
doc.save("D:/tho_dophu_15April.docx")
print("Đã lưu tài liệu vào file D:/tho_dophu_16April.docx")
# Out:
# Đã lưu tài liệu vào file D:/tho_dophu_16April.docx
